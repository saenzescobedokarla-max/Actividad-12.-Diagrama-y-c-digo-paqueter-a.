# %% [markdown]
# <a href="https://colab.research.google.com/github/saenzescobedokarla-max/Actividad-12.-Diagrama-y-c-digo-paqueter-a./blob/main/Actividad_11_Diagrama_y_codigo%2C_derecho_a_examen_karla_saenz_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("------Derecho a examen----")
Total_clase = int(input("ingrese el total de clases de clases de semestre: "))
asistencia = int(input(" ingrese las asistencias del alumno: "))
porcentaje = (asistencia/Total_clase)*100
if porcentaje > 80:
    print("el alumno puede presentar el examen")
else:
    print("el alumno no puede presentar examen")
# Out:
# ------Derecho a examen----
# ingrese el total de clases de clases de semestre: 10
#  ingrese las asistencias del alumno: 5
# el alumno no puede presentar examen

# %%
print("------Derecho a examen----")
Total_clase = int(input("ingrese el total de clases de clases de semestre: "))
asistencia = int(input(" ingrese las asistencias del alumno: "))
porcentaje = (asistencia/Total_clase)*100
if porcentaje > 80:
    print("el alumno puede presentar el examen")
else:
    print("el alumno no puede presentar examen")
# Out:
# ------Derecho a examen----
# ingrese el total de clases de clases de semestre: 30
#  ingrese las asistencias del alumno: 30
# el alumno puede presentar el examen

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/saenzescobedokarla-max/Actividad-12.-Diagrama-y-c-digo-paqueter-a./refs/heads/main/act11.png)
